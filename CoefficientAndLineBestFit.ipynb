# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")

data = data[['Age', 'MutRate']]
ages = []
MutRates = []
for x in data["Age"]:
    ages.append(x)
for x in data["MutRate"]:
    MutRates.append(x)

#f = open("ages.txt", "w")    
#g = open("mutrates.txt", "w")
#for x in range(len(ages)):
 #   f.write(str(ages[x]) + "\n")
  #g.write(str(MutRates[x])+"\n")
#g.close()
#f.close()

plt.scatter(data=data,x="Age",y="MutRate")
plt.ylabel("Mutation Rate")
plt.xlabel("Age")

x = pd.Series(ages)
y = pd.Series(MutRates)

x.corr(y)
#x.corr(y, method='spearman') 
#x.corr(y, method='kendall') 

#>>> scipy.stats.pearsonr(x, y)    # Pearson's r
#(0.7586402890911869, 0.010964341301680832)
#>>> scipy.stats.spearmanr(x, y)   # Spearman's rho
#SpearmanrResult(correlation=0.9757575757575757, pvalue=1.4675461874042197e-06)
#>>> scipy.stats.kendalltau(x, y)  # Kendall's tau
#KendalltauResult(correlation=0.911111111111111, pvalue=2.9761904761904762e-05)
# Out:
# -0.072051241451679

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")

data = data.loc[data["Ethnicity"] == "AFR" , :] 

ages = []
MutRates = []
for x in data["Age"]:
    ages.append(x)
for x in data["MutRate"]:
    MutRates.append(x)

plt.scatter(data=data,x="Age",y="MutRate")
plt.ylabel("Mutation Rate")
plt.xlabel("Age")

x = pd.Series(ages)
y = pd.Series(MutRates)

#x.corr(y)
print(x.corr(y).round(5))
#print(x.corr(y, method='spearman').round(5))
#plt.savefig('AgeMutrateAfrican.png')
# Out:
# 0.02862

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")

data = data.loc[data["Ethnicity"] == "EUR" , :] 

ages = []
MutRates = []
for x in data["Age"]:
    ages.append(x)
for x in data["MutRate"]:
    MutRates.append(x)

plt.scatter(data=data,x="Age",y="MutRate")
plt.ylabel("Mutation Rate")
plt.xlabel("Age")

x = pd.Series(ages)
y = pd.Series(MutRates)

#x.corr(y)
print(x.corr(y).round(5))
#print(x.corr(y, method='spearman').round(5))


#plt.savefig('AgeMutrateEur.png')
# Out:
# -0.10579

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")
data.rename(columns={'MutRate': 'Mutation Rate'}, inplace=True)
data = data.loc[data["Ethnicity"] == "EUR" , :] 
g = sns.lmplot(data=data, x="Age", y="Mutation Rate")
plt.savefig('LineBestFitEUR.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")
data.rename(columns={'MutRate': 'Mutation Rate'}, inplace=True)
data = data.loc[data["Ethnicity"] == "AFR" , :] 
g = sns.lmplot(data=data, x="Age", y="Mutation Rate")
plt.savefig('LineBestFitAFR.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")
data.rename(columns={'MutRate': 'Chromosome 20 Mutation Rate'}, inplace=True)
data.loc[data["Ethnicity"] == "EUR", "Ethnicity"] = "European"
data.loc[data["Ethnicity"] == "AFR", "Ethnicity"] = "African"
#data = data.loc[data["Ethnicity"] == "AFR" , :] 
g = sns.lmplot(data=data, x="Age", y="Chromosome 20 Mutation Rate", hue = "Ethnicity")
plt.savefig('LineBestFitAFR.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")
data.rename(columns={'MutRate': 'Chromosome 20 Mutation Rate'}, inplace=True)
#data = data.loc[data["Ethnicity"] == "AFR" , :] 
g = sns.lmplot(data=data, x="Age", y="Chromosome 20 Mutation Rate")
plt.savefig('LineBestFitEUR.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

#from scipy import stats

data = pd.read_csv("DonorMutsUSCSextract.tsv",sep = "\t")



ages = []
MutRates = []
for x in data["Age"]:
    ages.append(x)
for x in data["MutRate"]:
    MutRates.append(x)

plt.scatter(data=data,x="Age",y="MutRate")
plt.ylabel("Mutation Rate")
plt.xlabel("Age")

x = pd.Series(ages)
y = pd.Series(MutRates)

#x.corr(y)
#print(x.corr(y).round(5))
print(x.corr(y, method='spearman').round(5))
#plt.savefig('AgeMutrateAfrican.png')
# Out:
# -0.01096
